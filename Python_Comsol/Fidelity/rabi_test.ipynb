# %%
# %reload_ext autoreload
# %autoreload 2
# %reload_ext snakeviz

# %%
# Hi! #
### Shouldn't be necessary right now to import all of this but it is here for now in case something doesn't work

from qutip import *
import qutip
import matplotlib.pyplot as plt
import numpy
import scipy.optimize as sp_opt
import numpy as np
T = tensor
from qutip_rabi import *

#from tqdm.notebook import tqdm
import pandas as pd
import seaborn as sns
# Out:
# Running cells with 'c:\Users\Pratyush Anand\AppData\Local\Programs\Python\Python311\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Pratyush Anand/AppData/Local/Programs/Python/Python311/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
times = np.linspace(0,5e-6,int(1e4))

F_in=1
N=3
f0=5e9
Qmech=1e5
T1e=100e-6
g_sm=1e6
Temp=4
Delta_p=0
Delta_e=0

print(rabi_fidelity(
    times,
    F_in,
    N=N,
    f0=f0,
    Qmech=Qmech,
    T1e=T1e,
    g_sm=g_sm,
    Temp=Temp,
    Delta_p=Delta_p,
    Delta_e=Delta_e,
    plotting=True
))
# Out:
# 0.9435986457551545
